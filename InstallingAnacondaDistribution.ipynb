# %% [markdown]
# ## Using Python for Datascience projects ##
#
# *The open-source Anaconda Distribution is the easiest way to perform Python/R data science and machine learning on Linux, Windows, and Mac OS X. With over 11 million users worldwide, it is the industry standard for developing, testing, and training on a single machine, enabling individual data scientists to:*
#
# - Quickly download 1,500+ Python/R data science packages
# - Manage libraries, dependencies, and environments with Conda
# - Develop and train machine learning and deep learning models with scikit-learn, TensorFlow, and Theano
# - Analyze data with scalability and performance with Dask, NumPy, pandas, and Numba
# - Visualize results with Matplotlib, Bokeh, Datashader, and Holoviews
#
# *We shall use Jupyter Notebooks to execute python codes for datascience
# The Jupyter Notebook is an open-source web application that allows you to create and share documents that contain live code, equations, visualizations and narrative text. Uses include: data cleaning and transformation, numerical simulation, statistical modeling, data visualization, machine learning, and much more. Anaconda Distribution installs Jupyter Notebook to your system*

# %%
#Ignore the Code for the time being..We shall discuss this in later sections..
from IPython.display import Image
Fig_1 = Image(r'''C:\Users\sod04\Desktop\Python Tutorials\Anaconda_Dwl3.jpg''')
Fig_2 = Image(r'''C:\Users\sod04\Desktop\Python Tutorials\Anaconda_Dwl.jpg''')
Fig_3 = Image(r'''C:\Users\sod04\Desktop\Python Tutorials\Anaconda_Dwl2.jpg''')
Fig_4 = Image(r'''C:\Users\sod04\Desktop\Python Tutorials\Anaconda_Dwl4.jpg''')

# %%
Fig_1

# %% [markdown]
# **Step 1. To Download Ananconda Distribution visit the below Website**
# <br>
# https://www.anaconda.com/distribution/

# %%
Fig_2

# %% [markdown]
# **Step 2. Choose the right version to be downloaded depending whether you are using a Windows or Macbook**

# %%
Fig_3

# %% [markdown]
# *Once you have downloaded the distribution, install the package and follow the recommended steps. Usually it installs most packages required for Datascience and Analytics projects; however some may require installation. One such package is the **pandasql** package which allows SQL queries to be executed on pandas dataframes.
# <br>
# To do this, go to windows search, type Anaconda Prompt. Open the command prompt and then type
# <br>
# **$ pip install -U pandasql**
# *

# %% [markdown]
# #### Tip to convert the document into a slideshow
#
# *Go to View menu >> Cell Toolbar >> Slideshow*
# <br>
# *A Slide Type box will appear on the right of each cell as highlighted in yellow*

# %%
Fig_4

# %% [markdown]
# ***Choose the appropriate option from the various slide types given below***
#
# These widgets give you the following options:
#
# - Slide
# - Sub-Slide
# - Fragment
# - Skip
# - Notes
#
# *Now we just need to turn it into an actual slideshow. To do that, you will need save your Notebook and shut down the Jupyter Notebook server. Next you will need to run the following command:*
#
# **jupyter nbconver slideshow.ipynb -- to slides --post serve**
# <br>
#
# *where slideshow.ipynb is the name of your file*

# %% [markdown]
# #### *End of this section* ####
